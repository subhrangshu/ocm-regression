# %%
import pandas as pd
import numpy as np
import os

# %%
os.listdir('Extracted Datasets')
# Out:
# ['Combined_Data.csv',
#  'loc6_combined.csv',
#  'temp_bio_data.csv',
#  'temp_phy_data.csv']

# %%
combined = pd.read_csv('Extracted Datasets/Combined_Data.csv')
loc6 = pd.read_csv('Extracted Datasets/loc6_combined.csv')

# %%
combined.mean().round(6)
# Out:
# spco2          36.981963
# o2            235.536241
# chl             0.159008
# latitude        8.202819
# no3             3.777984
# po4             0.316071
# phyc            1.306461
# si              5.291371
# ph              8.060772
# nppv            3.344338
# longitude     -35.801096
# fe              0.000509
# mlotst         37.873536
# siconc          0.000000
# thetao         20.899030
# usi             0.000000
# sithick         0.000001
# bottomT         1.967186
# vsi             0.000000
# vo              0.014845
# uo              0.031496
# so             34.783922
# zos             0.120807
# year         2005.864526
# month           6.500000
# dtype: float64

# %%
combined
# Out:
#            time      spco2         o2       chl  latitude        no3  \
# 0       2000-01  31.765936  213.97511  0.093244      22.0   0.004902
# 1       2000-02  31.911985  215.47520  0.086183      22.0   0.004318
# 2       2000-03  33.540830  212.93338  0.088064      22.0   0.006213
# 3       2000-04  35.236195  208.32628  0.088673      22.0   0.005149
# 4       2000-05  37.714030  202.40598  0.089608      22.0   0.004710
# ...         ...        ...        ...       ...       ...        ...
# 168559  2018-08  37.748978  276.01200  0.339174     -40.0  10.462052
# 168560  2018-09  37.884846  266.17800  0.363841     -40.0   9.436721
# 168561  2018-10  38.285090  278.11404  0.350610     -40.0  10.440707
# 168562  2018-11  39.373806  277.29007  0.277200     -40.0  10.290730
# 168563  2018-12  40.665688  269.14752  0.300080     -40.0   9.855226
#
#              po4      phyc        si        ph  ...  usi  sithick   bottomT  \
# ...
